# %%
import pandas as pd
# Đọc file CSV
df = pd.read_csv("salary_survey_raw.csv")
print(f'Shape: {df.shape}')
# Out:
# Shape: (2800, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp                        2800 non-null   object
#  1   how_old_are_you                  2800 non-null   object
#  2   industry                         2800 non-null   object
#  3   job_title                        2800 non-null   object
#  4   additional_context_on_job_title  1831 non-null   object
#  5   annual_salary                    2409 non-null   object
#  6   additional_monetary_comp         1262 non-null   object
#  7   currency                         2800 non-null   object
#  8   income_context                   531 non-null    object
#  9   country                          2685 non-null   object
#  10  us_state                         987 non-null    object
#  11  city                             1238 non-null   object
#  12  years_of_experience_in_field     2800 non-null   object
#  13  years_of_experience_overall      2800 non-null   object
#  14  highest_level_of_education       2800 non-null   object
#  15  gender                           2731 non-null   object
#  16  race                             2034 non-null   object
# dtypes: object(17)
# memory usage: 372.0+ KB

# %%
miss = df.isnull().sum()
pct  = (miss / len(df) * 100).round(1)
report = pd.DataFrame({'count': miss, 'pct_%': pct})
report = report[report['count'] > 0].sort_values('pct_%', ascending=False)
print(report)
# Out:
#                                  count  pct_%
# income_context                    2269   81.0
# us_state                          1813   64.8
# city                              1562   55.8
# additional_monetary_comp          1538   54.9
# additional_context_on_job_title    969   34.6
# race                               766   27.4
# annual_salary                      391   14.0
# country                            115    4.1
# gender                              69    2.5

# %%
null_rate = df.isnull().mean().sort_values(ascending=False)
print(null_rate)
#Null hợp lệ là null có ý nghĩa
# Out:
# income_context                     0.810357
# us_state                           0.647500
# city                               0.557857
# additional_monetary_comp           0.549286
# additional_context_on_job_title    0.346071
# race                               0.273571
# annual_salary                      0.139643
# country                            0.041071
# gender                             0.024643
# timestamp                          0.000000
# how_old_are_you                    0.000000
# industry                           0.000000
# job_title                          0.000000
# currency                           0.000000
# years_of_experience_in_field       0.000000
# highest_level_of_education         0.000000
# years_of_experience_overall        0.000000
# dtype: float64

# %%
missing_cols_fill = df.columns[df.isnull().mean() < 0.3]
print(missing_cols_fill)
#Null cần điền  là null thiếu dữ kiệu có thể thay thế được
# Out:
# Index(['timestamp', 'how_old_are_you', 'industry', 'job_title',
#        'annual_salary', 'currency', 'country', 'years_of_experience_in_field',
#        'years_of_experience_overall', 'highest_level_of_education', 'gender',
#        'race'],
#       dtype='object')

# %%
missing_cols_investigate = df.columns[df.isnull().mean() > 0.5]
print(missing_cols_investigate)
#Null cần xem xét là null bất thường, ảnh hưởng lớn, không nên điền ngay
# Out:
# Index(['additional_monetary_comp', 'income_context', 'us_state', 'city'], dtype='object')

# %% [markdown]
# 1. Tại sao chúng ta không fillna(mean) cho cột lương?

# %% [markdown]
# Không nên fillna(mean) cho cột lương vì:
#
# Salary thường bị lệch và có outlier.
#
# Mean dễ bị kéo lên bởi người lương quá cao.
#
# Fill bằng mean sẽ tạo giá trị không thực tế.
#
# Nên dùng median hoặc median theo từng industry hợp lý hơn.

# %% [markdown]
#  2.Xử lý cột 'country' (null = 8%)

# %%
import pandas as pd
# Đọc file CSV
df = pd.read_csv("salary_survey_raw.csv")
print(f'Shape: {df.shape}')
# Out:
# Shape: (2800, 17)

# %%
country_mode = df['country'].mode()[0]

df['country'] = df['country'].fillna(country_mode)
print(df['country'].isnull().sum())
# Out:
# 0

# %% [markdown]
# 3.Xử lý cột 'years_of_experience' (null = 3%) , có cách nào làm mất ít thông tin hơn?

# %% [markdown]
# Có. Vì NULL chỉ khoảng 3% nên thay vì xóa dòng, ta nên fill để giữ dữ liệu.

# %%
df['years_of_experience_in_field'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['years_of_experience_in_field'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [timestamp, how_old_are_you, industry, job_title, additional_context_on_job_title, annual_salary, additional_monetary_comp, currency, income_context, country, us_state, city, years_of_experience_in_field, years_of_experience_overall, highest_level_of_education, gender, race]
# Index: []

# %%
experience_mode = df['years_of_experience_in_field'].mode()[0]

df['years_of_experience_in_field'] = df['years_of_experience_in_field'].fillna(experience_mode)
print(experience_mode)
# Out:
# 11 - 20 years

# %% [markdown]
# 4.Viết hàm missing_report() ngắn gọn

# %%
def missing_report(df):
    return pd.DataFrame({
        'Missing': df.isnull().sum(),
        'Percent': (df.isnull().mean() * 100).round(2)
    })
missing_report(df)
# Out:
#                                  Missing  Percent
# timestamp                              0     0.00
# how_old_are_you                        0     0.00
# industry                               0     0.00
# job_title                              0     0.00
# additional_context_on_job_title      969    34.61
# annual_salary                        391    13.96
# additional_monetary_comp            1538    54.93
# currency                               0     0.00
# income_context                      2269    81.04
# country                                0     0.00
# us_state                            1813    64.75
# city                                1562    55.79
# years_of_experience_in_field           0     0.00
# years_of_experience_overall            0     0.00
# highest_level_of_education             0     0.00
# gender                                69     2.46
# race                                 766    27.36

# %% [markdown]
# 1.Missing

# %%
import pandas as pd

# Missing report
def missing_report(df):
    return pd.DataFrame({
        'Missing': df.isnull().sum(),
        'Percent': (df.isnull().mean() * 100).round(2)
    })

print(missing_report(df))
# Out:
#                                  Missing  Percent
# timestamp                              0     0.00
# how_old_are_you                        0     0.00
# industry                               0     0.00
# job_title                              0     0.00
# additional_context_on_job_title      969    34.61
# annual_salary                        391    13.96
# additional_monetary_comp            1538    54.93
# currency                               0     0.00
# income_context                      2269    81.04
# country                                0     0.00
# us_state                            1813    64.75
# city                                1562    55.79
# years_of_experience_in_field           0     0.00
# years_of_experience_overall            0     0.00
# highest_level_of_education             0     0.00
# gender                                69     2.46
# race                                 766    27.36

# %% [markdown]
# 1.2Handle missing

# %%
# salary flag
df['salary_imputed'] = df['annual_salary'].isnull().astype(int)

# convert salary to numeric
df['annual_salary'] = (
    df['annual_salary']
    .astype(str)
    .str.replace(',', '')
)

df['annual_salary'] = pd.to_numeric(df['annual_salary'], errors='coerce')

# fill median theo industry
industry_median = df.groupby('industry')['annual_salary'].transform('median')

df['annual_salary'] = df['annual_salary'].fillna(industry_median)
print(df['annual_salary'].isnull().sum())
# Out:
# 0

# %% [markdown]
# 1.3 Remove Duplicated

# %%
print(df.duplicated().sum())

df = df.drop_duplicates()
# Out:
# 38

# %% [markdown]
# 1.4 Fix datatype

# %%
# salary về numeric
df = df.copy()
df['annual_salary'] = (
    df['annual_salary']
    .astype(str)
    .str.replace(',', '')
)

df['annual_salary'] = pd.to_numeric(df['annual_salary'], errors='coerce')
print(df['annual_salary'].head())
# Out:
# 0     56894.0
# 1    144543.0
# 2     52304.0
# 3     51765.0
# 4    133218.0
# Name: annual_salary, dtype: float64

# %%
print(df['annual_salary'].isnull().sum())#null còn không
# Out:
# 0

# %%
print(df['annual_salary'].dtype)# kiểm tra datatype
# Out:
# float64

# %% [markdown]
# 2. Decision Log
# Quyết định xử lý: Cột 'annual_salary_USD' — missing values
#
# Quan sát: Có nhiều giá trị NULL trong cột lương.
#
# Giả thuyết về nguyên nhân:
#
# Người dùng không muốn khai lương.
# Một số dữ liệu bị thiếu khi survey.
#
# Phương án đã xem xét:
#
# Drop hàng NULL
# Fill global mean
# Fill median theo industry
#
# Quyết định: Phương án 3 + thêm cột salary_imputed
#
# Lý do:
#
# Salary phụ thuộc ngành nghề.
# Median ít bị ảnh hưởng bởi outlier hơn mean.
# Quyết định xử lý: Cột 'country' — missing 8%
#
# Quan sát: Một phần nhỏ dữ liệu bị thiếu quốc gia.
#
# Giả thuyết về nguyên nhân:
#
# Người tham gia bỏ qua câu hỏi.
#
# Phương án đã xem xét:
#
# Drop rows
# Fill mode
#
# Quyết định: Fill bằng mode.
#
# Lý do:
#
# Missing thấp (~8%).
# Country là categorical data.
# Quyết định xử lý: Duplicate rows
#
# Quan sát: Dataset có duplicated rows.
#
# Giả thuyết về nguyên nhân:
#
# Submit survey nhiều lần.
# Lỗi import dữ liệu.
#
# Phương án đã xem xét:
#
# Giữ nguyên
# Drop duplicates
#
# Quyết định: Drop duplicates.
#
# Lý do:
#
# Duplicate làm sai kết quả thống kê và visualization.

# %%
# Phương pháp 1: IQR — tốt cho dữ liệu lệch phải
def detect_outliers_iqr(df, col):
Q1, Q3 = df[col].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower, upper = Q1 - 1.5*IQR, Q3 + 1.5*IQR
return df[(df[col] < lower) | (df[col] > upper)]
# Phương pháp 2: Z-score — tốt cho phân phối chuẩn
def detect_outliers_zscore(df, col, thresh=3):
z = (df[col] - df[col].mean()) / df[col].std()
return df[z.abs() > thresh]
# So sánh kết quả và giải thích sự khác biệt
# Out:
#   Cell In[1], line 3
#     Q1, Q3 = df[col].quantile([0.25, 0.75])
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
def detect_outliers(df, col):
    Q1, Q3 = df[col].quantile([0.25, 0.75])

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return df[(df[col] < lower) | (df[col] > upper)]

# %%
import pandas as pd

# =========================
# 1. Đọc file CSV
# =========================
df = pd.read_csv("salary_survey_raw.csv")

print("Shape:", df.shape)
print(df.head())


# =========================
# 2. Missing Values Report
# =========================
def missing_report(df):
    miss = df.isnull().sum()
    pct = (miss / len(df) * 100).round(2)

    return (
        pd.DataFrame({
            'missing_count': miss,
            'missing_pct': pct
        })
        .query('missing_count > 0')
        .sort_values('missing_pct', ascending=False)
    )

print("\n=== Missing Report ===")
print(missing_report(df))


# =========================
# 3. Missing Values Handling
# =========================

# Lưu null trước xử lý
before_null = df.isnull().sum()


# age -> fill median
if 'age' in df.columns:
    df['age'] = df['age'].fillna(df['age'].median())


# country -> fill text
if 'country' in df.columns:
    df['country'] = df['country'].fillna('Unknown')


# salary -> interpolate nếu numeric
if 'salary' in df.columns:
    df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
    df['salary'] = df['salary'].interpolate()


# note/comment -> fill text
if 'note' in df.columns:
    df['note'] = df['note'].fillna('none')


# Null sau xử lý
after_null = df.isnull().sum()


# So sánh trước/sau
compare_null = pd.DataFrame({
    'before_null': before_null,
    'after_null': after_null
})

print("\n=== Null Comparison ===")
print(compare_null)


# =========================
# 4. Duplicate Check
# =========================

before_rows = len(df)

# Duplicate toàn hàng
n_dup = df.duplicated().sum()

print(f"\nDuplicate rows: {n_dup} ({n_dup/len(df)*100:.1f}%)")


# Duplicate theo key columns
if 'email' in df.columns and 'timestamp' in df.columns:
    key_dup = df.duplicated(subset=['email', 'timestamp']).sum()
    print(f"Duplicate by key columns: {key_dup}")


# Xóa duplicate
df = df.drop_duplicates(keep='first').reset_index(drop=True)

after_rows = len(df)

print(f"Rows before: {before_rows}")
print(f"Rows after : {after_rows}")


# =========================
# 5. Outlier Detection
# =========================

def detect_outliers(df, col):

    Q1, Q3 = df[col].quantile([0.25, 0.75])

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    return outliers


# Kiểm tra outlier salary
if 'salary' in df.columns:
    outliers = detect_outliers(df, 'salary')

    print("\n=== Salary Outliers ===")
    print(outliers.head())


# =========================
# 6. Dataset sau xử lý
# =========================
print("\n=== Final Shape ===")
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       1 import pandas as pd
#       3 # =========================
#       4 # 1. Đọc file CSV
#       5 # =========================
# ----> 6 df = pd.read_csv("salary_survey_raw.csv")
#       8 print("Shape:", df.shape)
#       9 print(df.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'salary_survey_raw.csv'
