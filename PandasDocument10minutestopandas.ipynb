# %%
import numpy as np
import pandas as pd

# %%
In [3]: s = pd.Series([1, 3, 5, np.nan, 6, 8])

In [4]: s
# dạng dataframe là kiểu Float64 dữ liệu số thực dấu phẩy động 64-bit
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
In [5]: dates = pd.date_range("20130101", periods=6)

In [6]: dates


In [7]: df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

In [8]: df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.895318  0.000839 -0.114767  2.334651
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594
# 2013-01-06  0.038595  0.198025  2.427457 -0.721941

# %%
In [9]: df2 = pd.DataFrame(
   ...:     {
   ...:         "A": 1.0,
   ...:         "B": pd.Timestamp("20130102"),
   ...:         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
   ...:         "D": np.array([3] * 4, dtype="int32"),
   ...:         "E": pd.Categorical(["test", "train", "test", "train"]),
   ...:         "F": "foo",
   ...:     }
   ...: )
   ...: 

In [10]: df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
In [11]: df2.dtype
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
In [12]: df2.<TAB>  # noqa: E225, E999
#khi gõ dfr2. sau đó bấm <TAB> thì sẽ hiện lên tính năng Tab Completition(tên cột,các hàm,thuộc tính có thể dùng)
#A là truy cập cột A,abs là giá trị tuyệt đối,apply là áp sụng hàm,colums là cột,describe là thống kê dữ liệu,copylaf sao chép dataframe

df2.A                  df2.bool
df2.abs                df2.boxplot
df2.add                df2.C
df2.add_prefix         df2.clip
df2.add_suffix         df2.columns
df2.align              df2.copy
df2.all                df2.count
df2.any                df2.combine
df2.append             df2.D
df2.apply              df2.describe
df2.B                  df2.duplicated
df2.diff

# %%
In [13]: df.head()
#dùng dataframe.head()  để xem hàng trên cùng và hàng dưới cùng của khung
# Out:
#                    A         B         C         D
# 2013-01-01 -0.895318  0.000839 -0.114767  2.334651
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594

# %%
In [14]: df.tail(3)
#dùng dataframe.tail()  để xem hàng trên cùng và hàng dưới cùng của khung (lấy 3 dòng cuối của df)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594
# 2013-01-06  0.038595  0.198025  2.427457 -0.721941

# %%
In [15]: df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
In [16]: df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
In [17]: df.to_numpy()
#Trả về một đối tượng NumPy biểu diễn dữ liệu gốc bằng phương thức DataFrame.to_numpy() mà không bao gồm chỉ mục hoặc nhãn cột:
# Out:
# array([[-8.95318422e-01,  8.39035339e-04, -1.14766913e-01,
#          2.33465118e+00],
#        [-1.65508633e+00,  1.10980624e+00,  1.10293565e+00,
#          1.84562230e-01],
#        [ 5.90388060e-01,  1.39903706e+00,  8.62801523e-01,
#         -2.47574230e-02],
#        [-1.48043964e+00, -1.09423855e+00,  8.19089908e-01,
#         -1.68503070e-01],
#        [-1.39419158e+00, -2.12800240e+00, -1.05297270e+00,
#         -5.80594149e-01],
#        [ 3.85950619e-02,  1.98024982e-01,  2.42745728e+00,
#         -7.21940951e-01]])

# %%
In [18]: df2.dtypes
#Mảng NumPy có một kiểu dữ liệu duy nhất cho toàn bộ mảng, trong khi DataFrame của pandas có một kiểu dữ liệu riêng cho mỗi cột. Khi bạn gọi DataFrame.to_numpy(), pandas sẽ tìm kiểu dữ liệu NumPy có thể chứa tất cả các kiểu dữ liệu trong DataFrame. Nếu kiểu dữ liệu chung là object, thì DataFrame.to_numpy() sẽ yêu cầu sao chép dữ liệu.
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
In [19]: df2.to_numpy()
#Mảng NumPy có một kiểu dữ liệu duy nhất cho toàn bộ mảng, trong khi DataFrame của pandas có một kiểu dữ liệu riêng cho mỗi cột. Khi bạn gọi DataFrame.to_numpy(), pandas sẽ tìm kiểu dữ liệu NumPy có thể chứa tất cả các kiểu dữ liệu trong DataFrame. Nếu kiểu dữ liệu chung là object, thì DataFrame.to_numpy() sẽ yêu cầu sao chép dữ liệu.
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
In [20]: df.describe()
#Hàm describe() hiển thị bản tóm tắt thống kê nhanh về dữ liệu
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.799342 -0.085756  0.674091  0.170570
# std    0.915722  1.334902  1.176425  1.113318
# min   -1.655086 -2.128002 -1.052973 -0.721941
# 25%   -1.458878 -0.820469  0.118697 -0.477571
# 50%   -1.144755  0.099432  0.840946 -0.096630
# 75%   -0.194883  0.881861  1.042902  0.132232
# max    0.590388  1.399037  2.427457  2.334651

# %%
In [21]: df.T
#Chuyển đổi dữ liệu
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.895318   -1.655086    0.590388   -1.480440   -1.394192    0.038595
# B    0.000839    1.109806    1.399037   -1.094239   -2.128002    0.198025
# C   -0.114767    1.102936    0.862802    0.819090   -1.052973    2.427457
# D    2.334651    0.184562   -0.024757   -0.168503   -0.580594   -0.721941

# %%
In [22]: df.sort_index(axis=1, ascending=False)
#df.sort_index Sắp xếp theo một trục
# Out:
#                    D         C         B         A
# 2013-01-01  2.334651 -0.114767  0.000839 -0.895318
# 2013-01-02  0.184562  1.102936  1.109806 -1.655086
# 2013-01-03 -0.024757  0.862802  1.399037  0.590388
# 2013-01-04 -0.168503  0.819090 -1.094239 -1.480440
# 2013-01-05 -0.580594 -1.052973 -2.128002 -1.394192
# 2013-01-06 -0.721941  2.427457  0.198025  0.038595

# %%
In [23]: df.sort_values(by="B")
#Sắp xếp theo giá trị
# Out:
#                    A         B         C         D
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503
# 2013-01-01 -0.895318  0.000839 -0.114767  2.334651
# 2013-01-06  0.038595  0.198025  2.427457 -0.721941
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757

# %%
In [24]: df["A"]
#Đối với DataFrame, việc truyền một nhãn duy nhất sẽ chọn một cột và trả về một Series
# Out:
# 2013-01-01   -0.895318
# 2013-01-02   -1.655086
# 2013-01-03    0.590388
# 2013-01-04   -1.480440
# 2013-01-05   -1.394192
# 2013-01-06    0.038595
# Freq: D, Name: A, dtype: float64

# %%
In [25]: df.A
#Nếu nhãn chỉ chứa chữ cái, số và dấu gạch dưới, bạn có thể sử dụng thuộc tính tên cột thay thế:
# Out:
# 2013-01-01   -0.895318
# 2013-01-02   -1.655086
# 2013-01-03    0.590388
# 2013-01-04   -1.480440
# 2013-01-05   -1.394192
# 2013-01-06    0.038595
# Freq: D, Name: A, dtype: float64

# %%
In [26]: df[["B", "A"]]
#Việc truyền vào một danh sách các nhãn cột sẽ chọn nhiều cột, điều này có thể hữu ích để lấy một tập con/sắp xếp lại dữ liệu:
# Out:
#                    B         A
# 2013-01-01  0.000839 -0.895318
# 2013-01-02  1.109806 -1.655086
# 2013-01-03  1.399037  0.590388
# 2013-01-04 -1.094239 -1.480440
# 2013-01-05 -2.128002 -1.394192
# 2013-01-06  0.198025  0.038595

# %%
In [27]: df[0:3]
#Đối với DataFrame, việc truyền một slice: chọn các hàng phù hợp:
# Out:
#                    A         B         C         D
# 2013-01-01 -0.895318  0.000839 -0.114767  2.334651
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757

# %%
In [28]: df["20130102":"20130104"]
##Đối với DataFrame, việc truyền một slice: chọn các hàng phù hợp:
# Out:
#                    A         B         C         D
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503

# %%
In [29]: df.loc[dates[0]]
#Chọn một hàng khớp với nhãn:
# Out:
# A   -0.895318
# B    0.000839
# C   -0.114767
# D    2.334651
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
In [30]: df.loc[:, ["A", "B"]]
#Chọn tất cả các hàng (:) bằng cách sử dụng nhãn cột đã chọn:
# Out:
#                    A         B
# 2013-01-01 -0.895318  0.000839
# 2013-01-02 -1.655086  1.109806
# 2013-01-03  0.590388  1.399037
# 2013-01-04 -1.480440 -1.094239
# 2013-01-05 -1.394192 -2.128002
# 2013-01-06  0.038595  0.198025

# %%
In [31]: df.loc["20130102":"20130104", ["A", "B"]]
#Đối với việc cắt nhãn, cả hai điểm cuối đều được bao gồm:
# Out:
#                    A         B
# 2013-01-02 -1.655086  1.109806
# 2013-01-03  0.590388  1.399037
# 2013-01-04 -1.480440 -1.094239

# %%
In [32]: df.loc[dates[0], "A"]
#Việc chọn một hàng và nhãn cột duy nhất sẽ trả về một giá trị vô hướng:
# Out:
# np.float64(-0.8953184220490983)

# %%
In [33]: df.at[dates[0], "A"]
#Để truy cập nhanh vào một giá trị vô hướng (tương đương với phương pháp trước đó)
# Out:
# np.float64(-0.8953184220490983)

# %%
In [34]: df.iloc[3]
#Chọn dựa trên vị trí của các số nguyên được truyền vào:
# Out:
# A   -1.480440
# B   -1.094239
# C    0.819090
# D   -0.168503
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
In [35]: df.iloc[3:5, 0:2]
#Các lát cắt số nguyên hoạt động tương tự như NumPy/Python:
# Out:
#                    A         B
# 2013-01-04 -1.480440 -1.094239
# 2013-01-05 -1.394192 -2.128002

# %%
In [36]: df.iloc[[1, 2, 4], [0, 2]]
#Danh sách các vị trí số nguyên:
# Out:
#                    A         C
# 2013-01-02 -1.655086  1.102936
# 2013-01-03  0.590388  0.862802
# 2013-01-05 -1.394192 -1.052973

# %%
In [37]: df.iloc[1:3, :]
#Để cắt các hàng một cách rõ ràng:
# Out:
#                    A         B         C         D
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757

# %%
In [38]: df.iloc[:, 1:3]
#Để cắt các cột một cách rõ ràng:
# Out:
#                    B         C
# 2013-01-01  0.000839 -0.114767
# 2013-01-02  1.109806  1.102936
# 2013-01-03  1.399037  0.862802
# 2013-01-04 -1.094239  0.819090
# 2013-01-05 -2.128002 -1.052973
# 2013-01-06  0.198025  2.427457

# %%
In [39]: df.iloc[1, 1]
#Để lấy giá trị một cách rõ ràng:
# Out:
# np.float64(1.109806240390186)

# %%
In [40]: df.iat[1, 1]
#Để truy cập nhanh vào một giá trị vô hướng (tương đương với phương pháp trước đó):
# Out:
# np.float64(1.109806240390186)

# %%
In [41]: df[df["A"] > 0]
#Chọn các hàng có df.A lớn hơn 0.
# Out:
#                    A         B         C         D
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757
# 2013-01-06  0.038595  0.198025  2.427457 -0.721941

# %%
In [42]: df[df > 0]
#Chọn các giá trị từ DataFrame khi điều kiện boolean được đáp ứng:
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.000839       NaN  2.334651
# 2013-01-02       NaN  1.109806  1.102936  0.184562
# 2013-01-03  0.590388  1.399037  0.862802       NaN
# 2013-01-04       NaN       NaN  0.819090       NaN
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06  0.038595  0.198025  2.427457       NaN

# %%
In [43]: df2 = df.copy()

In [44]: df2["E"] = ["one", "one", "two", "three", "four", "three"]

In [45]: df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.895318  0.000839 -0.114767  2.334651    one
# 2013-01-02 -1.655086  1.109806  1.102936  0.184562    one
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757    two
# 2013-01-04 -1.480440 -1.094239  0.819090 -0.168503  three
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594   four
# 2013-01-06  0.038595  0.198025  2.427457 -0.721941  three

# %%
In [46]: df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.590388  1.399037  0.862802 -0.024757   two
# 2013-01-05 -1.394192 -2.128002 -1.052973 -0.580594  four

# %%
In [47]: s1 = pd.Series(
   ....:    [1, 2, 3, 4, 5, 6],
   ....:    index=pd.date_range("20130102", periods=6))
   ....: 

In [48]: s1
#Việc thiết lập cột mới sẽ tự động căn chỉnh dữ liệu theo chỉ mục:
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
In [50]: df.at[dates[0], "A"] = 0
#Thiết lập giá trị theo nhãn:

# %%
In [51]: df.iat[0, 1] = 0
#Thiết lập giá trị theo vị trí:

# %%
In [52]: df.loc[:, "D"] = np.array([5] * len(df))
#Thiết lập bằng cách gán với một mảng NumPy:

# %%
In [53]: df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.114767  5.0
# 2013-01-02 -1.655086  1.109806  1.102936  5.0
# 2013-01-03  0.590388  1.399037  0.862802  5.0
# 2013-01-04 -1.480440 -1.094239  0.819090  5.0
# 2013-01-05 -1.394192 -2.128002 -1.052973  5.0
# 2013-01-06  0.038595  0.198025  2.427457  5.0

# %%
In [54]: df2 = df.copy()

In [55]: df2[df2 > 0] = -df2

In [56]: df2
#Một thao tác với thiết lập:
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.114767 -5.0
# 2013-01-02 -1.655086 -1.109806 -1.102936 -5.0
# 2013-01-03 -0.590388 -1.399037 -0.862802 -5.0
# 2013-01-04 -1.480440 -1.094239 -0.819090 -5.0
# 2013-01-05 -1.394192 -2.128002 -1.052973 -5.0
# 2013-01-06 -0.038595 -0.198025 -2.427457 -5.0

# %%
In [57]: df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

In [58]: df1.loc[dates[0] : dates[1], "E"] = 1

In [59]: df1
#Việc lập chỉ mục lại cho phép bạn thay đổi/thêm/xóa chỉ mục trên một trục cụ thể. Thao tác này trả về một bản sao của dữ liệu:
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.114767  5.0  1.0
# 2013-01-02 -1.655086  1.109806  1.102936  5.0  1.0
# 2013-01-03  0.590388  1.399037  0.862802  5.0  NaN
# 2013-01-04 -1.480440 -1.094239  0.819090  5.0  NaN

# %%
In [60]: df1.dropna(how="any")
#DataFrame.dropna() sẽ xóa bất kỳ hàng nào có dữ liệu bị thiếu:
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.114767  5.0  1.0
# 2013-01-02 -1.655086  1.109806  1.102936  5.0  1.0

# %%
In [61]: df1.fillna(value=5)
#Phương thức DataFrame.fillna() điền dữ liệu bị thiếu:
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -0.114767  5.0  1.0
# 2013-01-02 -1.655086  1.109806  1.102936  5.0  1.0
# 2013-01-03  0.590388  1.399037  0.862802  5.0  5.0
# 2013-01-04 -1.480440 -1.094239  0.819090  5.0  5.0

# %%
In [62]: pd.isna(df1)
#isna() lấy boolean cho các giá trị là nan:
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
In [63]: df.mean()
#Tính giá trị trung bình cho mỗi cột:
# Out:
# A   -0.650122
# B   -0.085895
# C    0.674091
# D    5.000000
# dtype: float64

# %%
In [64]: df.mean(axis=1)
#Tính giá trị trung bình cho mỗi hàng:
# Out:
# 2013-01-01    1.221308
# 2013-01-02    1.389414
# 2013-01-03    1.963057
# 2013-01-04    0.811103
# 2013-01-05    0.106208
# 2013-01-06    1.916019
# Freq: D, dtype: float64

# %%
In [65]: s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

In [66]: s
#Thao tác với một Series hoặc DataFrame khác có chỉ mục hoặc cột khác nhau sẽ căn chỉnh kết quả với hợp nhất các nhãn chỉ mục hoặc cột. Ngoài ra, pandas tự động mở rộng theo chiều được chỉ định và sẽ điền các nhãn không được căn chỉnh bằng np.nan.
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
In [67]: df.sub(s, axis="index")
#Thao tác với một Series hoặc DataFrame khác có chỉ mục hoặc cột khác nhau sẽ căn chỉnh kết quả với hợp nhất các nhãn chỉ mục hoặc cột. Ngoài ra, pandas tự động mở rộng theo chiều được chỉ định và sẽ điền các nhãn không được căn chỉnh bằng np.nan.
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -0.409612  0.399037 -0.137198  4.0
# 2013-01-04 -4.480440 -4.094239 -2.180910  2.0
# 2013-01-05 -6.394192 -7.128002 -6.052973  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
In [68]: df.agg(lambda x: np.mean(x) * 5.6)
#Các phương thức DataFrame.agg() và DataFrame.transform() áp dụng một hàm do người dùng định nghĩa để giảm kích thước hoặc mở rộng kết quả tương ứng.
# Out:
# A    -3.640685
# B    -0.481014
# C     3.774908
# D    28.000000
# dtype: float64

# %%
In [69]: df.transform(lambda x: x * 101.2)
#Các phương thức DataFrame.agg() và DataFrame.transform() áp dụng một hàm do người dùng định nghĩa để giảm kích thước hoặc mở rộng kết quả tương ứng.
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000    0.000000  -11.614412  506.0
# 2013-01-02 -167.494737  112.312392  111.617088  506.0
# 2013-01-03   59.747272  141.582551   87.315514  506.0
# 2013-01-04 -149.820491 -110.736942   82.891899  506.0
# 2013-01-05 -141.092188 -215.353843 -106.560837  506.0
# 2013-01-06    3.905820   20.040128  245.658677  506.0

# %%
In [70]: s = pd.Series(np.random.randint(0, 7, size=10))

In [71]: s
# Out:
# 0    3
# 1    0
# 2    5
# 3    0
# 4    1
# 5    6
# 6    0
# 7    2
# 8    1
# 9    6
# dtype: int32

# %%
In [72]: s.value_counts()
# Out:
# 0    3
# 1    2
# 6    2
# 3    1
# 5    1
# 2    1
# Name: count, dtype: int64

# %%
In [73]: s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

In [74]: s.str.lower()
#Lớp Series được trang bị một tập hợp các phương thức xử lý chuỗi trong thuộc tính `str` giúp dễ dàng thao tác trên từng phần tử của mảng, như trong đoạn mã bên dưới.
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
In [75]: df = pd.DataFrame(np.random.randn(10, 4))

In [76]: df
# Out:
#           0         1         2         3
# 0  0.669983  0.759978 -2.066029  1.037325
# 1 -1.707780 -1.325599  0.181586 -1.308563
# 2  0.098434 -0.054529  0.482305  0.340247
# 3 -0.657232 -1.005734  0.198705 -0.092808
# 4 -1.459511 -0.558697 -1.033523 -0.034151
# 5 -2.048788  0.888973  1.446267  0.134369
# 6  0.005100  0.507576 -1.015624 -1.790159
# 7 -0.300647 -0.566342 -2.270077 -2.190562
# 8 -0.293731 -1.469687  1.254763  0.259552
# 9 -1.301860  0.542567 -2.705919 -0.291882

# %%
In [77]: pieces = [df[:3], df[3:7], df[7:]]
In [78]: pd.concat(pieces)
Nối các đối tượng pandas lại với nhau theo từng hàng bằng hàm concat():
# Out:
#           0         1         2         3
# 0  0.669983  0.759978 -2.066029  1.037325
# 1 -1.707780 -1.325599  0.181586 -1.308563
# 2  0.098434 -0.054529  0.482305  0.340247
# 3 -0.657232 -1.005734  0.198705 -0.092808
# 4 -1.459511 -0.558697 -1.033523 -0.034151
# 5 -2.048788  0.888973  1.446267  0.134369
# 6  0.005100  0.507576 -1.015624 -1.790159
# 7 -0.300647 -0.566342 -2.270077 -2.190562
# 8 -0.293731 -1.469687  1.254763  0.259552
# 9 -1.301860  0.542567 -2.705919 -0.291882

# %%
In [79]: left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

In [80]: right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

In [81]: left
#Hàm merge() cho phép thực hiện các kiểu kết nối SQL dọc theo các cột cụ thể. Xem phần Kết nối kiểu cơ sở dữ liệu.
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
In [82]: right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
In [83]: pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
In [84]: left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

In [85]: right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

In [86]: left
#merge() trên các khóa duy nhất:
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
In [87]: right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
In [88]: pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
In [89]: df = pd.DataFrame(
   ....:     {
   ....:         "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
   ....:         "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
   ....:         "C": np.random.randn(8),
   ....:         "D": np.random.randn(8),
   ....:     }
   ....: )
   ....: 

In [90]: df
#Thuật ngữ “nhóm theo” đề cập đến một quy trình bao gồm một hoặc nhiều bước sau:

#Chia dữ liệu thành các nhóm dựa trên một số tiêu chí

#Áp dụng một hàm cho từng nhóm một cách độc lập

#Kết hợp các kết quả thành một cấu trúc dữ liệu
# Out:
#      A      B         C         D
# 0  foo    one  0.609882  0.348589
# 1  bar    one -1.024753 -1.729733
# 2  foo    two  0.739780  0.939849
# 3  bar  three  0.362608  0.041601
# 4  foo    two  0.566180 -0.136688
# 5  bar    two  0.017651  1.166422
# 6  foo    one  0.921901 -1.404804
# 7  foo  three  1.079640 -0.567188

# %%
In [91]: df.groupby("A")[["C", "D"]].sum()
#Thực hiện việc nhóm theo nhãn cột, chọn các nhãn cột, sau đó áp dụng hàm DataFrameGroupBy.sum() cho các nhóm kết quả:
# Out:
#             C         D
# A
# bar -0.644494 -0.521710
# foo  3.917382 -0.820242

# %%
In [92]: df.groupby(["A", "B"]).sum()
#Việc nhóm theo nhiều cột tạo thành MultiIndex.
# Out:
#                   C         D
# A   B
# bar one   -1.024753 -1.729733
#     three  0.362608  0.041601
#     two    0.017651  1.166422
# foo one    1.531782 -1.056214
#     three  1.079640 -0.567188
#     two    1.305960  0.803160

# %%
In [93]: arrays = [
   ....:    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ....:    ["one", "two", "one", "two", "one", "two", "one", "two"],
   ....: ]
   ....: 

In [94]: index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

In [95]: df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

In [96]: df2 = df[:4]

In [97]: df2
#Tái cấu trúc
#Xem các phần về Lập chỉ mục phân cấp và Tái cấu trúc.
# Out:
#                      A         B
# first second
# bar   one    -0.598344 -0.830249
#       two    -1.720765  1.187823
# baz   one     0.305051  2.162580
#       two     0.550511 -0.319102

# %%
In [98]: stacked = df2.stack()

In [99]: stacked
#Phương thức stack() “nén” một cấp độ trong các cột của DataFrame:
# Out:
# first  second
# bar    one     A   -0.598344
#                B   -0.830249
#        two     A   -1.720765
#                B    1.187823
# baz    one     A    0.305051
#                B    2.162580
#        two     A    0.550511
#                B   -0.319102
# dtype: float64

# %%
In [100]: stacked.unstack()
#Với DataFrame hoặc Series "xếp chồng" (có MultiIndex làm chỉ mục), thao tác ngược lại của stack() là unstack(), theo mặc định sẽ hủy xếp chồng cấp độ cuối cùng:
# Out:
#                      A         B
# first second
# bar   one    -0.598344 -0.830249
#       two    -1.720765  1.187823
# baz   one     0.305051  2.162580
#       two     0.550511 -0.319102

# %%
In [101]: stacked.unstack(1)
#Với DataFrame hoặc Series "xếp chồng" (có MultiIndex làm chỉ mục), thao tác ngược lại của stack() là unstack(), theo mặc định sẽ hủy xếp chồng cấp độ cuối cùng:
# Out:
# second        one       two
# first
# bar   A -0.598344 -1.720765
#       B -0.830249  1.187823
# baz   A  0.305051  0.550511
#       B  2.162580 -0.319102

# %%
In [102]: stacked.unstack(0)
#Với DataFrame hoặc Series "xếp chồng" (có MultiIndex làm chỉ mục), thao tác ngược lại của stack() là unstack(), theo mặc định sẽ hủy xếp chồng cấp độ cuối cùng:
# Out:
# first          bar       baz
# second
# one    A -0.598344  0.305051
#        B -0.830249  2.162580
# two    A -1.720765  0.550511
#        B  1.187823 -0.319102

# %%
In [103]: df = pd.DataFrame(
   .....:     {
   .....:         "A": ["one", "one", "two", "three"] * 3,
   .....:         "B": ["A", "B", "C"] * 4,
   .....:         "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
   .....:         "D": np.random.randn(12),
   .....:         "E": np.random.randn(12),
   .....:     }
   .....: )
   .....: 

In [104]: df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.372805 -0.765348
# 1     one  B  foo -2.276179  0.533123
# 2     two  C  foo -1.789884  0.250448
# 3   three  A  bar -1.158986 -0.294162
# 4     one  B  bar  0.178791  0.008897
# 5     one  C  bar  0.740252 -2.957471
# 6     two  A  foo -0.089259 -1.865973
# 7   three  B  foo  2.786915 -0.267912
# 8     one  C  foo -0.865822  0.311350
# 9     one  A  bar -1.009300 -1.089516
# 10    two  B  bar  0.068264 -0.371325
# 11  three  C  bar  2.145755 -0.138736

# %%
In [105]: pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
#Hàm pivot_table() xoay bảng (pivot_table) để xoay một DataFrame, chỉ định các giá trị, chỉ mục và cột.
# Out:
# C             bar       foo
# A     B
# one   A -1.009300 -0.372805
#       B  0.178791 -2.276179
#       C  0.740252 -0.865822
# three A -1.158986       NaN
#       B       NaN  2.786915
#       C  2.145755       NaN
# two   A       NaN -0.089259
#       B  0.068264       NaN
#       C       NaN -1.789884

# %%
In [106]: rng = pd.date_range("1/1/2012", periods=100, freq="s")

In [107]: ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

In [108]: ts.resample("5Min").sum()
#Thư viện pandas có chức năng đơn giản, mạnh mẽ và hiệu quả để thực hiện các thao tác lấy mẫu lại trong quá trình chuyển đổi tần số (ví dụ: chuyển đổi dữ liệu giây thành dữ liệu 5 phút). Điều này cực kỳ phổ biến trong các ứng dụng tài chính, nhưng không giới hạn ở đó
# Out:
# 2012-01-01    23023
# Freq: 5min, dtype: int32

# %%
In [109]: rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

In [110]: ts = pd.Series(np.random.randn(len(rng)), rng)

In [111]: ts
#Hàm Series.tz_localize() định vị chuỗi thời gian theo múi giờ:
# Out:
# 2012-03-06    1.586081
# 2012-03-07    1.375851
# 2012-03-08    0.319145
# 2012-03-09    0.577729
# 2012-03-10    0.110285
# Freq: D, dtype: float64

# %%
In [112]: ts_utc = ts.tz_localize("UTC")

In [113]: ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.586081
# 2012-03-07 00:00:00+00:00    1.375851
# 2012-03-08 00:00:00+00:00    0.319145
# 2012-03-09 00:00:00+00:00    0.577729
# 2012-03-10 00:00:00+00:00    0.110285
# Freq: D, dtype: float64

# %%
In [114]: ts_utc.tz_convert("US/Eastern")
#Hàm Series.tz_convert() chuyển đổi chuỗi thời gian có nhận biết múi giờ sang một múi giờ khác:
# Out:
# 2012-03-05 19:00:00-05:00    1.586081
# 2012-03-06 19:00:00-05:00    1.375851
# 2012-03-07 19:00:00-05:00    0.319145
# 2012-03-08 19:00:00-05:00    0.577729
# 2012-03-09 19:00:00-05:00    0.110285
# Freq: D, dtype: float64

# %%
In [115]: rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
In [116]: rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
In [117]: df = pd.DataFrame(
   .....:     {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
   .....: )
   .....: 
   #Pandas có thể bao gồm dữ liệu phân loại trong DataFrame.

# %%
In [118]: df["grade"] = df["raw_grade"].astype("category")

In [119]: df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
In [120]: new_categories = ["very good", "good", "very bad"]

In [121]: df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
In [122]: df["grade"] = df["grade"].cat.set_categories(
   .....:     ["very bad", "bad", "medium", "good", "very good"]
   .....: )
   .....: 

In [123]: df["grade"]
#Sắp xếp lại các danh mục và đồng thời thêm các danh mục còn thiếu (các phương thức trong Series.cat() mặc định trả về một Series mới):
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
In [124]: df.sort_values(by="grade")
#Việc sắp xếp được thực hiện theo thứ tự trong các danh mục, chứ không phải theo thứ tự từ vựng:
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
In [125]: df.groupby("grade", observed=False).size()
#Việc nhóm theo cột phân loại có observed=False cũng hiển thị các danh mục trống:
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
In [126]: import matplotlib.pyplot as plt

In [127]: plt.close("all")

# %%
In [128]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

In [129]: ts = ts.cumsum()

In [130]: ts.plot();

# %%
In [131]: df = pd.DataFrame(
   .....:     np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
   .....: )
   .....: 

In [132]: df = df.cumsum()

In [133]: plt.figure();

In [134]: df.plot();

In [135]: plt.legend(loc='best');

# %%
In [136]: df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

In [137]: df.to_csv("foo.csv")
#viết file csv sbanwgf việc sử dụng df,to_csv

# %%
In [138]: pd.read_csv("foo.csv")
#đọc file csv bằng df.read_csv
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  2  4  3  4
# 1           1  4  1  2  3  3
# 2           2  2  0  2  1  1
# 3           3  0  2  4  4  4
# 4           4  3  4  1  0  2
# 5           5  2  3  2  1  0
# 6           6  2  0  4  0  0
# 7           7  1  0  4  1  2
# 8           8  2  3  0  1  3
# 9           9  0  0  2  1  0

# %%
In [139]: df.to_parquet("foo.parquet")
#Ghi dữ liệu vào tệp Parquet:

# %%
In [140]: pd.read_parquet("foo.parquet")
#đọc tệp parquet
# Out:
#    0  1  2  3  4
# 0  0  2  4  3  4
# 1  4  1  2  3  3
# 2  2  0  2  1  1
# 3  0  2  4  4  4
# 4  3  4  1  0  2
# 5  2  3  2  1  0
# 6  2  0  4  0  0
# 7  1  0  4  1  2
# 8  2  3  0  1  3
# 9  0  0  2  1  0

# %%
In [141]: df.to_excel("foo.xlsx", sheet_name="Sheet1")
#Ghi dữ liệu vào tệp Excel bằng cách sử dụng DataFrame.to_excel():

# %%
In [142]: pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
#Đọc dữ liệu từ tệp Excel bằng hàm read_excel():
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  2  4  3  4
# 1           1  4  1  2  3  3
# 2           2  2  0  2  1  1
# 3           3  0  2  4  4  4
# 4           4  3  4  1  0  2
# 5           5  2  3  2  1  0
# 6           6  2  0  4  0  0
# 7           7  1  0  4  1  2
# 8           8  2  3  0  1  3
# 9           9  0  0  2  1  0

# %%
In [143]: if pd.Series([False, True, False]):
   .....:      print("I was true")
   .....: 
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
Cell In[143], line 1
----> 1 if pd.Series([False, True, False]):
      2      print("I was true")

File ~/work/pandas/pandas/pandas/core/generic.py:1513, in NDFrame.__bool__(self)
   1511     @final
   1512     def __bool__(self) -> NoReturn:
-> 1513         raise ValueError(
   1514             f"The truth value of a {type(self).__name__} is ambiguous. "
   1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
   1516         )

ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# Out:
#   Cell In[118], line 4
#     ---------------------------------------------------------------------------
#                                                                                ^
# SyntaxError: invalid syntax
